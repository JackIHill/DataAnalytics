# %%
import pandas as pd
import os

# %%
cwd = os.getcwd()

# %%
data = pd.read_excel(cwd + '\\Solo Data\\Solo Data - Raw Survey Monkey Output.xlsx', sheet_name='Edited_data')

# %%
data = data.drop(columns=['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1 '])

# %%
id_vars = list(data.columns[:10])
value_vars = list(data.columns[10:])

data_melted = pd.melt(data, id_vars=id_vars, value_vars=value_vars, var_name='Question+Subquestion', value_name='Answer')
data_melted
# Out:
#        Respondent ID  Identify which division you work in. - Response  \
# 0          5379192392                                  Infrastructure
# 1          2658722536                                         Finance
# 2          4044163394                                  Infrastructure
# 3          5535865599                                  Infrastructure
# 4          3356802928                                 Port Operations
# ...               ...                                             ...
# 16627      7940065082                                  Infrastructure
# 16628      5157705612                                         Finance
# 16629      9920755555                                 Port Operations
# 16630      6638341389                                  Infrastructure
# 16631      8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16627                                                NaN
# 16628                                                NaN
# 16629                                                NaN
# 16630                                                NaN
# 16631                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 16627                                    Department Lead
# 16628                                              Staff
# 16629                                              Staff
# 16630                                            Manager
# 16631                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 16627          Baby Boomer (born between 1946-1964)
# 16628           Millennial (born between 1981-2000)
# 16629           Millennial (born between 1981-2000)
# 16630           Millennial (born between 1981-2000)
# 16631                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 16627                                               Male
# 16628                                             Female
# 16629                                             Female
# 16630                                             Female
# 16631                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 16627                                          10+ years
# 16628                                         5-10 years
# 16629                                          3-5 years
# 16630                                          3-5 years
# 16631                                         5-10 years
#
#       Which of the following best describes your employment type? - Response  \
# 0                                     Full time Employee
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 16627                                 Full time Employee
# 16628                                 Full time Employee
# 16629                                 Full time Employee
# 16630                                 Full time Employee
# 16631                                 Full time Employee
#
#       Question 1 - Response Question 2 - Response  \
# 0                       NaN              Answer 6
# 1                  Answer 4              Answer 2
# 2                  Answer 5              Answer 7
# 3                  Answer 1              Answer 1
# 4                       NaN              Answer 3
# ...                     ...                   ...
# 16627              Answer 3                   NaN
# 16628                   NaN                   NaN
# 16629                   NaN              Answer 7
# 16630                   NaN                   NaN
# 16631                   NaN              Answer 1
#
#                    Question+Subquestion    Answer
# 0      Question 3 - Open-Ended Response       NaN
# 1      Question 3 - Open-Ended Response       NaN
# 2      Question 3 - Open-Ended Response       NaN
# 3      Question 3 - Open-Ended Response  Answer 7
# 4      Question 3 - Open-Ended Response  Answer 5
# ...                                 ...       ...
# 16627          Question 30 - Response 3  Answer 8
# 16628          Question 30 - Response 3  Answer 6
# 16629          Question 30 - Response 3       NaN
# 16630          Question 30 - Response 3       NaN
# 16631          Question 30 - Response 3       NaN
#
# [16632 rows x 12 columns]

# %%
question_data = pd.read_excel('Solo Data\\Solo Data - Raw Survey Monkey Output.xlsx', sheet_name='Questions')
question_data.drop(columns=['Response', 'Question.1'], inplace=True)
question_data
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID           Respondent ID -
# 1      Start Date              Start Date -
# 2        End Date                End Date -
# 3   Email Address           Email Address -
# 4      First Name              First Name -
# ..            ...                        ...
# 95            NaN  Question 29 - Response 13
# 96            NaN  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98            NaN   Question 30 - Response 2
# 99            NaN   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
data_merged = data_melted.copy()
data_merged = pd.merge(left=data_merged, right=question_data, left_on='Question+Subquestion', right_on='Question + Subquestion')
data_merged.head()
